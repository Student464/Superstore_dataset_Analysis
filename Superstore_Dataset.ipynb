# %% [markdown]
# <a href="https://colab.research.google.com/github/Student464/Superstore_dataset_Analysis/blob/main/Superstore_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Lode the data set**

# %%
# load the dataset
df = pd.read_csv("/content/SuperStoreOrders.csv")

# %%
# To see first 5 columns and rows(head) of the dataset
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
# To remove the unwanted columns from dataset
df.drop(columns=["order_id","customer_name","product_id"])
# Out:
#        order_date ship_date       ship_mode      segment             state  \
# 0        1/1/2011  6/1/2011  Standard Class     Consumer       Constantine
# 1        1/1/2011  8/1/2011  Standard Class     Consumer   New South Wales
# 2        1/1/2011  5/1/2011    Second Class     Consumer          Budapest
# 3        1/1/2011  5/1/2011    Second Class  Home Office         Stockholm
# 4        1/1/2011  8/1/2011  Standard Class     Consumer   New South Wales
# ...           ...       ...             ...          ...               ...
# 51285  31-12-2014  4/1/2015  Standard Class    Corporate        California
# 51286  31-12-2014  5/1/2015  Standard Class     Consumer  Souss-Massa-Draâ
# 51287  31-12-2014  2/1/2015    Second Class     Consumer           Managua
# 51288  31-12-2014  6/1/2015  Standard Class     Consumer         Chihuahua
# 51289  31-12-2014  4/1/2015  Standard Class     Consumer          Colorado
#
# ...

# %%
df.drop(columns=["order_id","customer_name","product_id"],inplace=True)

# %%
df.head()
# Out:
#   order_date ship_date       ship_mode      segment            state  \
# 0   1/1/2011  6/1/2011  Standard Class     Consumer      Constantine
# 1   1/1/2011  8/1/2011  Standard Class     Consumer  New South Wales
# 2   1/1/2011  5/1/2011    Second Class     Consumer         Budapest
# 3   1/1/2011  5/1/2011    Second Class  Home Office        Stockholm
# 4   1/1/2011  8/1/2011  Standard Class     Consumer  New South Wales
#
#      country  market   region         category sub_category  \
# 0    Algeria  Africa   Africa  Office Supplies      Storage
# 1  Australia    APAC  Oceania  Office Supplies     Supplies
# 2    Hungary    EMEA     EMEA  Office Supplies      Storage
# 3     Sweden      EU    North  Office Supplies        Paper
# 4  Australia    APAC  Oceania        Furniture  Furnishings
#
#                   product_name sales  quantity  discount   profit  \
# 0          Tenex Lockers, Blue   408         2       0.0  106.140
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.shape
# Out:
# (51290, 18)

# %%
df.head().corr()
# Out:
# <ipython-input-38-707a585af533>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.head().corr()
#                quantity  discount    profit  shipping_cost  year
# quantity       1.000000 -0.084591 -0.347444      -0.727282   NaN
# discount      -0.084591  1.000000 -0.805056      -0.459913   NaN
# profit        -0.347444 -0.805056  1.000000       0.862228   NaN
# shipping_cost -0.727282 -0.459913  0.862228       1.000000   NaN
# year                NaN       NaN       NaN            NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_date      51290 non-null  object
#  1   ship_date       51290 non-null  object
#  2   ship_mode       51290 non-null  object
#  3   segment         51290 non-null  object
#  4   state           51290 non-null  object
#  5   country         51290 non-null  object
#  6   market          51290 non-null  object
#  7   region          51290 non-null  object
#  8   category        51290 non-null  object
#  9   sub_category    51290 non-null  object
#  10  product_name    51290 non-null  object
#  11  sales           51290 non-null  object
#  12  quantity        51290 non-null  int64
#  13  discount        51290 non-null  float64
#  14  profit          51290 non-null  float64
#  15  shipping_cost   51290 non-null  float64
#  16  order_priority  51290 non-null  object
# ...

# %%
# to describe the data set
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
# to identify the null cells of given dataset
df.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
# to know what are the unique values in that column
print(df["year"].unique())
print(df["quantity"].unique())
print(df["segment"].unique())
print(df["ship_mode"].unique())
print(df["market"].unique())
print(df["region"].unique())
print(df["category"].unique())
print(df["sub_category"].unique())
print(df["order_priority"].unique())
# Out:
# [2011 2012 2013 2014]
# [ 2  3  4  5  1  7  6  8  9 10 11 12 14 13]
# ['Consumer' 'Home Office' 'Corporate']
# ['Standard Class' 'Second Class' 'Same Day' 'First Class']
# ['Africa' 'APAC' 'EMEA' 'EU' 'Canada' 'LATAM' 'US']
# ['Africa' 'Oceania' 'EMEA' 'North' 'Canada' 'Southeast Asia' 'Central'
#  'South' 'Caribbean' 'North Asia' 'East' 'West' 'Central Asia']
# ['Office Supplies' 'Furniture' 'Technology']
# ['Storage' 'Supplies' 'Paper' 'Furnishings' 'Machines' 'Appliances'
#  'Copiers' 'Chairs' 'Tables' 'Bookcases' 'Phones' 'Accessories' 'Labels'
#  'Art' 'Envelopes' 'Fasteners' 'Binders']
# ['Medium' 'High' 'Critical' 'Low']

# %%
# Discount analysis based on year
df.groupby("year")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# here in 2014 the discount was more as compared to other years

# %%
# Discount analysis based on quantity
df.groupby("quantity")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='quantity'>

# %%
# Discount analysis based on segment
df.groupby("segment")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='segment'>

# %% [markdown]
# based on our analysis in consumer segment the more discount can be obtain

# %%
# Discount analysis based on ship_mode
df.groupby("ship_mode")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='ship_mode'>

# %% [markdown]
# based on our analysis in standard class the more discount can be obtain

# %%
# Discount analysis based on market
df.groupby("market")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='market'>

# %% [markdown]
# based on our analysis in APAC market the more discount can be obtain

# %%
# Discount analysis based on region
df.groupby("region")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# based on our analysis in central region the more discount can be obtain

# %%
# Discount analysis based on category
df.groupby("category")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# based on our analysis in office Supplies category the more discount can be obtain

# %%
# Discount analysis based on sub_category
df.groupby("sub_category")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='sub_category'>

# %% [markdown]
# based on our analysis in Binders sub_category the more discount can be obtain

# %%
# Discount analysis based on order_priority
df.groupby("order_priority")["discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='order_priority'>

# %% [markdown]
# based on our analysis in medium order_priority the more discount can be obtain

# %%
df.groupby("year")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("segment")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("ship_mode")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("market")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("region")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("category")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("sub_category")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
df.groupby("order_priority")["discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='discount'>

# %%
import plotly.express as px
fig = px.imshow(df.head().corr(),text_auto=True)
fig.show()
# Out:
# <ipython-input-23-63bf1b188802>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fig = px.imshow(df.head().corr(),text_auto=True)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
ax=sns.heatmap(df.corr(),annot=True,cbar=True,square=True,linecolor="blue",linewidths=1,xticklabels="auto",yticklabels="auto",fmt=".2f")
ax.set(xlabel="", ylabel="")
ax.xaxis.tick_top()
# Out:
# <ipython-input-37-0939353d14a1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax=sns.heatmap(df.corr(),annot=True,cbar=True,square=True,linecolor="blue",linewidths=1,xticklabels="auto",yticklabels="auto",fmt=".2f")
